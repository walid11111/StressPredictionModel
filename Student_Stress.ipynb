# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# self estem mean: self-esteem is how much you value and feel confident about yourself.
##---> High Self-Esteem: If you have high self-esteem, you generally feel good about yourself and believe in your abilities
##--->f you have low self-esteem, you might often feel unworthy, doubt your abilities, 


### Mental _health_history  (catagorical data also plot graph     find Counts and Percentages: Calculate the number and percentage of individuals with and without a mental health history.)
### 0: No history of mental health issues.
### 1: Has a history of mental health issues

# %%
df=pd.read_csv('W:\\jupyter\\StressLevelDataset.csv')

# %% [markdown]
# ### How big is the Data

# %%
# Number of Rows and Columns
df.shape
# Out:
# (1100, 21)

# %% [markdown]
# ### How does the Data look like

# %%
df.head()
#df.sample(5)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %% [markdown]
# ### what is the DataTypes of Cols

# %%
# Information about columns datatypes
df.info()     # so all the columns are inter types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %% [markdown]
# ### Is there any missing values in a dataset

# %%
# to check any null values are present in the clomuns
df.isnull().sum()
# Out:
# anxiety_level                   0
# self_esteem                     0
# mental_health_history           0
# depression                      0
# headache                        0
# blood_pressure                  0
# sleep_quality                   0
# breathing_problem               0
# noise_level                     0
# living_conditions               0
# safety                          0
# basic_needs                     0
# academic_performance            0
# study_load                      0
# teacher_student_relationship    0
# future_career_concerns          0
# social_support                  0
# peer_pressure                   0
# extracurricular_activities      0
# bullying                        0
# stress_level                    0
# dtype: int64

# %% [markdown]
# ### So thier is no missing values in a dataset

# %% [markdown]
# ### what does the Data look Mathematicaly

# %%
# To check all the Summory of the dataset like (mean, max ,min,count,std and so on)
df.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %% [markdown]
# ### Are thier any duplicate values are availible or not

# %%
df.duplicated().sum()    # so there are no duplicate values in a dataset
# Out:
# np.int64(0)

# %% [markdown]
# ### How is the correlation between the columns

# %%
  # this show correlation between all the clomuns with stress level

# %% [markdown]
# # 1: Catagorical columns Analysis (Univariat Analysis)

# %% [markdown]
# ## Calculate the Number of Students at Each Stress Level
# ### ----> Now i want to find how many students occure in deferrent level of stress

# %%
# Count the number of people at each stress level
print("THERE ARE TOTAL 1100 HUNDERED STUDENTS")
stress_level_counts = df['stress_level'].value_counts().sort_index()

# Display the counts
for i in stress_level_counts.index:
    print(f"Level {i}: {stress_level_counts[i]} Students")
# Out:
# THERE ARE TOTAL 1100 HUNDERED STUDENTS
# Level 0: 373 Students
# Level 1: 358 Students
# Level 2: 369 Students

# %% [markdown]
# ### create a pie chart to visualize the stress level of a Students

# %%
plt.figure(figsize=(8, 6))
#labels = [f'Level {i}' for i in stress_level_counts.index]
label=['Level 0','Level 1','Level 2']
plt.pie(stress_level_counts,autopct='%1.1f%%',labels=label)
plt.title('Distribution of Stress Levels Among Students')
#plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the plot
plt.show()

# %% [markdown]
# ### Now i want to find how many students occure in mental_health_history means(0 --> NO issue, 1--->issue)

# %%
# Count the number of people at mental health history
mental_health_counts = df['mental_health_history'].value_counts().sort_index()

# Display the counts
for category in mental_health_counts.index:
    print(f"History Category {category}: {mental_health_counts[category]} Students")
# Out:
# History Category 0: 558 Students
# History Category 1: 542 Students

# %% [markdown]
# ## create a count plot to visualize the mental health History of a Students

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='mental_health_history', data=df, palette='pastel', linewidth=3, hue='mental_health_history')
plt.title('Distribution of Mental Health History of Students')
plt.xlabel('History Category')
plt.ylabel('Count')
plt.xticks([0, 1], ['Category 0', 'Category 1'])  # Customizing x-axis tick labels
plt.show()

# %% [markdown]
# ## ABOUT THE Above CHART
# ### -->Now in the above char we can easy identify that category 0: is about 558 stduent that mental health history is
# ###      no issue so at stress level will bi low level
# ### -->On the other hand the catogory 1: is about 522 that is some issue that why it is stress level will be High

# %%
# blood pressure is aslo catogirical data but it dose not more effect on Stress level

# %% [markdown]
# # 2: Numerical column Analysis

# %% [markdown]
# ## Now we want to visualize the anxiety_level column to see how many students have high anxiety levels and how many have low anxiety levels By using.
# # Histogram

# %%
df['anxiety_level'].max()
# Out:
# np.int64(21)

# %%
df['anxiety_level'].min()
# Out:
# np.int64(0)

# %%
# Visualize the distribution of anxiety levels 
plt.figure(figsize=(8, 6))
plt.hist(df['anxiety_level'], bins=10, color='red', edgecolor='black')
plt.title('Distribution of Anxiety Levels Among Students')
plt.xlabel('Anxiety Level')
plt.ylabel('Frequency')
plt.grid(linewidth=0.2)
plt.show()

# %% [markdown]
# ### Now in the above graph we can clearly see the studends numbers in y_axis and thier anxiety Level. so its easy to predict it

# %%
if'depression' in df.columns:
    print("yes")
# Out:
# yes

# %% [markdown]
# # Displot

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['depression'], color='blue')
plt.title('Distribution of Depression Levels Among Students')
plt.xlabel('Depression Level')
plt.ylabel('Frequency')
plt.grid(linewidth=0.2)
plt.show()

# %% [markdown]
# ### so thebaove boxplot clearly show the meadian mean and nad maximumn and there are not outliear

# %% [markdown]
# # Bivariate and Multiple variate Analysis

# %% [markdown]
# ### I want to viusilaize how many depression level will be increase that it effect the stress level

# %%
sns.barplot(x='stress_level',y='depression',hue='stress_level', data=df, palette='pastel')
plt.title("Depression level vs Stress level")
plt.title("Depression Level vs Stress Level")
plt.xlabel('Stress Level')
plt.ylabel('Depression Level')
# Out:
# Text(0, 0.5, 'Depression Level')

# %% [markdown]
# ## Understanding the above Plot:
#
# Stress Levels:
# The X-axis values are discrete categories (0, 1, 2).
# These categories represent different levels of stress.
#
# Depression Levels:
# The Y-axis represents the depression levels associated with each stress level.
# The height of each bar shows the average depression level for that stress level.'''
#
# ### Bar Plot Insights:
# Stress Level 0:
# Has the lowest depression level.
#
# Stress Level 1:
# Has a moderate depression level.
#
# Stress Level 2:
# Has the highest depression level.

# %% [markdown]
# ## NOW TO COMPARE THE DEPRESSION LEVEL WITH STUDY LOAD (using the 2D plot)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x='study_load', y='depression', data=df, color='b',linestyle='--',linewidth=2,marker='o',markersize='10')
plt.title("Study Load vs Depression")
plt.xlabel('Study Load')
plt.ylabel('Depression Level')
plt.grid(True)
plt.show()

# %% [markdown]
# ### about the line Graph above:
# In the above we line graphs we compare the that how many student study load increase that will increase the depression level
# we see that the study load is but depression some reason may be suppose (the student his exam but it not a prepare at self that why
# and some there are in very low study level it take more depreesion )

# %% [markdown]
# # Study Load vs Depression with Stress Level( using scatterplot)
# When increasing study load and depression levels can potentially lead to increased stress levels among students. To visualize how stress levels might relate to both study load and depression,
# X-axis: Represents study load.

# %%
# Assuming 'stress_level' is another variable in your DataFrame 'df'

# Scatter plot with study load and depression, color mapped to stress level
plt.figure(figsize=(10, 8))
scatter = sns.scatterplot(x='study_load', y='depression', size='stress_level', hue='stress_level', data=df, palette='viridis', sizes=(50, 200), legend='brief')

plt.title("Study Load vs Depression with Stress Level")
plt.xlabel('Study Load')
plt.ylabel('Depression Level')
plt.legend(title='Stress Level', loc='upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# ---> When increasing study load and depression levels can potentially lead to increased stress levels among students. To visualize how stress levels might relate to both study load and depression,
# X-axis: Represents study load.
# Y-axis: Represents depression level.
# Point size or color: Represents stress level.
# This plot will help you visualize how increasing study load and depression levels might correspond to higher stress levels among students,

# %% [markdown]
# # Now Create a pair plot for the Student stress level Dataset
# ### pair plots means we make relationships among all numericals columns of the student stress level datset( but here we make some important colmuns  relationships )

# %%
# Create the pair plot
pair_plot = sns.pairplot(df[['stress_level', 'anxiety_level', 'self_esteem', 'depression', 'sleep_quality', 'noise_level', 'study_load', 'future_career_concerns']], hue='stress_level', palette='pastel')

# Set the title using the figure's suptitle
pair_plot.fig.suptitle("Pair Plot of Some Numerical Columns in Student Stress Dataset", y=1.02)

# Adjust layout to make space for the title
plt.subplots_adjust(top=0.99)

# Show the plot
plt.show()

# %% [markdown]
# so the above pair plot we can easy get information about this columns

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %% [markdown]
# # Standarization:
#  ### for best model perfomance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['mental_health_history','breathing_problem','blood_pressure','noise_level',
             'living_conditions','safety','teacher_student_relationship',	
              'extracurricular_activities','stress_level'],axis=1)
y=df['stress_level']
X_train, X_test, y_train, y_test = train_test_split(x,y , test_size=0.2, random_state=42)

print(X_train.shape, X_test.shape)
# Displaying the first few rows before scaling
print("First few rows of X_train before scaling:")
print(X_train.head())
print("First few rows of X_test before scaling:")
print(X_test.head())
# Out:
# (880, 12) (220, 12)
# First few rows of X_train before scaling:
#      anxiety_level  self_esteem  depression  headache  sleep_quality  \
# 507              9           17          10         2              2
# 551             12           17          13         3              2
# 290              9           30           2         3              3
# 2               12           18          14         2              2
# 6                4           26           6         1              4
#
#      basic_needs  academic_performance  study_load  future_career_concerns  \
# 507            2                     2           3                       2
# 551            2                     3           2                       3
# 290            0                     1           4                       2
# 2              2                     2           3                       2
# 6              4                     5           1                       1
#
# ...

# %%
# scaling the feature
from sklearn.preprocessing import StandardScaler
# Standardizing the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Display the shapes of the scaled data
print(X_train_scaled.shape, X_test_scaled.shape)


# Converting the scaled arrays back to DataFrames for better readability  o)
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test.columns)  

# Displaying the first few rows after scaling
print("First few rows of X_train after scaling:")
print(X_train_scaled_df.head())
print("First few rows of X_test after scaling:")
print(X_test_scaled_df.head())
# Out:
# (880, 12) (220, 12)
# First few rows of X_train after scaling:
#    anxiety_level  self_esteem  depression  headache  sleep_quality  \
# 0      -0.346572    -0.070883   -0.337648 -0.375811      -0.419290
# 1       0.144281    -0.070883    0.055208  0.333875      -0.419290
# 2      -0.346572     1.379742   -1.385265  0.333875       0.230314
# 3       0.144281     0.040704    0.186160 -0.375811      -0.419290
# 4      -1.164660     0.933396   -0.861456 -1.085497       0.879918
#
#    basic_needs  academic_performance  study_load  future_career_concerns  \
# 0    -0.548431             -0.545242    0.298254               -0.434142
# 1    -0.548431              0.156239   -0.458124                0.216701
# 2    -1.949357             -1.246722    1.054632               -0.434142
# 3    -0.548431             -0.545242    0.298254               -0.434142
# 4     0.852495              1.559200   -1.214503               -1.084986
#
#    social_support  peer_pressure  bullying
# ...

# %%
mean_train = X_train_scaled_df.mean()
std_train = X_train_scaled_df.std()
print("Training Data Mean:\n", mean_train)
print("Training Data Standard Deviation:\n", std_train)

mean_test = X_test_scaled_df.mean()
std_test = X_test_scaled_df.std()
print("Test Data Mean:\n", mean_test)
print("Test Data Standard Deviation:\n", std_test)
# Out:
# Training Data Mean:
#  anxiety_level            -1.534126e-16
# self_esteem              -1.372639e-16
# depression                3.330669e-17
# headache                 -1.831868e-16
# sleep_quality            -4.642751e-17
# basic_needs               1.413011e-16
# academic_performance     -2.018587e-17
# study_load                1.201059e-16
# future_career_concerns   -1.816729e-17
# social_support           -1.170781e-16
# peer_pressure             2.018587e-18
# bullying                  7.418308e-17
# dtype: float64
# Training Data Standard Deviation:
#  anxiety_level             1.000569
# self_esteem               1.000569
# depression                1.000569
# headache                  1.000569
# sleep_quality             1.000569
# basic_needs               1.000569
# academic_performance      1.000569
# study_load                1.000569
# future_career_concerns    1.000569
# social_support            1.000569
# peer_pressure             1.000569
# ...

# %% [markdown]
# #  Predictive Modelin:
# ### I have slect the randomforestclassifier algorithm beacouse our dataset is classification

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Training the Random Forest model for classification
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_scaled_df, y_train)

# Making predictions on the test set
y_pred = model.predict(X_test_scaled_df)

# Evaluating the model using accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Displaying the first few predictions
print("First few predictions:")
print(y_pred[:5])
# Out:
# Accuracy: 0.8954545454545455
# First few predictions:
# [2 0 1 1 0]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
